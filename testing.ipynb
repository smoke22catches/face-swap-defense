# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Out:
# README.md  datasets/            model/           test_encoder.py  weights/
# config.py  environment.yml      precompute.py    testing.ipynb
# data/      environment_cpu.yml  test_decoder.py  train.py
